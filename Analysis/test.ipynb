# %%
# %matplotlib inline
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('samples/gagok.csv', parse_dates=False)

# %%
df['t'] = pd.DatetimeIndex(df['t'])

# %%
# resample to 1 week
df2 = df[df.t<'2020-01-10'].set_index('t').resample('H').mean()
plt.plot(df2['level'], linewidth=1)

# %%
df2 = df[df.t>'2020-11-30']

# %%
plt.plot(df['level'])

# %%
plt.rcParams["figure.figsize"] = (15,5)
# set thickness of the line to 1
plt.plot(df['t'][df.t>'2020-10-01'], df['level'][df.t>'2020-10-01'], 'r-', linewidth=1)
